# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg, count, desc, round, explode, split, trim

spark = SparkSession.builder \
    .appName("AnimeAnalysis") \
    .getOrCreate()

df = spark.read.option("header", "true") \
    .option("quote", "\"") \
    .option("escape", "\"") \
    .csv("anime_recommendation_dataset.csv")

df.printSchema()

def split_genres_into_tuples(row):
    title = row.title
    genres = row.genres
    if genres:
        genre_list = [genre.strip() for genre in genres.split(",")]
        return [(title, genre) for genre in genre_list]
    return []

anime_rdd = df.rdd
genre_tuples_rdd = anime_rdd.flatMap(split_genres_into_tuples)

print("=== First 10 Genre-Title Pairs ===")
first_10_genres = genre_tuples_rdd.take(10)
for title, genre in first_10_genres:
    print(f"{title}: {genre}")

unique_genres = genre_tuples_rdd.map(lambda x: x[1]).distinct().collect()
print(f"\n=== Unique Genres ({len(unique_genres)} total) ===")

unique_genres = [genre for genre in unique_genres if genre and not genre[0].isdigit()]
print(sorted(unique_genres))

genre_count_rdd = genre_tuples_rdd.map(lambda x: (x[1], 1)).reduceByKey(lambda a, b: a + b)
print("\n=== Number of Anime per Genre ===")
genre_counts = genre_count_rdd.collect()

genre_counts = [(genre, genre_count_value) for genre, genre_count_value in genre_counts if genre and not genre[0].isdigit()]
for genre, genre_count_value in sorted(genre_counts, key=lambda x: x[1], reverse=True):
    print(f"{genre}: {genre_count_value} anime")


print("\n=== Top 5 Highest Rated Anime ===")

top_rated = df.filter(col("score").isNotNull()) \
    .select("title", "score", "genres") \
    .withColumn("score_float", col("score").cast("float")) \
    .orderBy(desc("score_float")) \
    .limit(5)

top_rated.show(truncate=False)


print("\n=== Average Score per Genre ===")

genre_df = df.withColumn("genre", explode(split(col("genres"), ","))) \
    .withColumn("genre", trim(col("genre"))) \
    .filter(col("score").isNotNull()) \
    .withColumn("score_float", col("score").cast("float"))

avg_score_by_genre = genre_df.groupBy("genre") \
    .agg(round(avg("score_float"), 2).alias("average_score"),
         count("title").alias("anime_count")) \
    .orderBy(desc("average_score"))

avg_score_by_genre.show(truncate=False)

print("\n=== Average Number of Episodes per Genre ===")
episodes_by_genre = genre_df.filter(col("episodes").isNotNull()) \
    .withColumn("episodes_float", col("episodes").cast("float")) \
    .groupBy("genre") \
    .agg(round(avg("episodes_float"), 1).alias("avg_episodes"),
         count("title").alias("anime_count")) \
    .orderBy(desc("avg_episodes"))

episodes_by_genre.show(truncate=False)

print("\n=== Genre with Highest Average Score (min 5 anime) ===")
top_genre = avg_score_by_genre.filter(col("anime_count") >= 5) \
    .orderBy(desc("average_score")) \
    .first()

if top_genre:
    print(f"Genre: {top_genre['genre']}")
    print(f"Average Score: {top_genre['average_score']}")
    print(f"Number of Anime: {top_genre['anime_count']}")

print("\n=== Most Common Genre Combinations ===")
genre_combinations = df.groupBy("genres") \
    .agg(count("title").alias("count")) \
    .orderBy(desc("count")) \
    .limit(10)

genre_combinations.show(truncate=False)

spark.stop()
# Out:
# root
#  |-- title: string (nullable = true)
#  |-- synopsis: string (nullable = true)
#  |-- genres: string (nullable = true)
#  |-- episodes: string (nullable = true)
#  |-- score: string (nullable = true)
#  |-- characters: string (nullable = true)
#
# === First 10 Genre-Title Pairs ===
# While traveling: the beautiful and ridiculously poor gambler
# (Source: Anime News Network)": 1.0
# Oddly enough: there's no proof that he's ever taken a life. In fact
# (Source: Funimation)": 26.0
# (Source: Funimation)": 26.0
# Bouken Ou Beet: Adventure
# Bouken Ou Beet: Fantasy
# Bouken Ou Beet: Supernatural
# (Source: Sentai Filmworks)": 145.0
# (Source: Anime News Network)": 24.0
#
# === Unique Genres (111 total) ===
# ['Action', 'Adventure', 'Aya Mikage is a descendent of Ceres', 'Ayato Kamina meets Reika Mishima', 'Comedy', 'Dr. Tenma\'s beliefs are shaken as his actions that night are shown to have much broader consequences than he could have imagined. Leaving behind his life as a surgeon he embarks on a journey across the country to unravel the mystery of the boy he saved."', 'Drama', 'Ecchi', 'Fantasy', 'Fokker', 'Hanamichi tells her he loves basketball', 'Horror', 'Keitaro thinks he will fail the paper and tries to escape from Hinata Lodge and forget all the memories with it. By a stroke of luck he meets Seta', 'Kirara', 'Mahou Shoujo', 'Mecha', 'Michelle', 'Music', 'Mystery', 'Nina', 'Psychological', 'Romance', 'Ryoko (the manager who`s sweet on Koji by working him very hard)', 'Sci-Fi', 'Shanghai', 'Slice of Life', 'Sports', 'Supernatural', 'Susuki gets to work to find the killer. While digging for the killer', 'Yui is given the power to become <i>Corrector Yui</i> so that she can fight against Grosser and his evil Corruptors.<br>', 'a Light Tribe sorceress who has been taken captive. As Astral penetrates Maria', 'a city that also serves as a fortress', 'a girl who was a childhood friend of his appeared. But', 'and Shiine', 'and he meets many friends and foes along the way. <br><br>', 'and one version which has lost all sexual content.</i>"', 'and the efforts of the Crossbone Vanguard militia', "and upon her singing his mother appears atop the Dolem that had stopped the TERRA Invasion. In the battle Ayato's mother is injured", 'but her relationship with an ex-worker for her evil grandpa may be a distraction. "', 'but the girl', 'coincidentally designed in part by his estranged mother', "disguising themselves as human beings. They feed off blood and hide themselves within the human world. An organization known as the Red Shield has been waging a private war to wipe them out and now the struggle has grown. Saya's journey for the truth has begun.<br>", 'engages the creature in an attempt to save his village. During the battle', 'hardened', 'has been shattered. The warring tribes of Light and Shadow blame each other', 'has escaped and is being hunted by the RUC Security Bureau. She encounters the bounty hunter Roy and he adopts her as his daughter after being hired as a bodygaurd for Miranda.<br><br>', 'has the power to see the dreams of other people in his sleep. He was also taught magic by an old lady that allows him to create sweets.<br><br>', 'he attempts to create peace and befriend the Wolf Clan. However', 'he learns of their problems and decides to help', 'he’ll go up against koala karate masters', 'his feelings have begun to change. Lecherous Makoto', 'including new and updated animation', 'industrial realm ruled by a despot named Dall. If they ever want to make it back to El-Hazard', 'informing him that she was sent
# purple-mohawked bruisers and pencil-chomping street thugs are just part of every day life. And so is a 400-pound gorilla. And a macho brute named Freddie who travels with his own theme music. And: 1 anime
# industrial realm ruled by a despot named Dall. If they ever want to make it back to El-Hazard: 1 anime
# notorious for its low success rate and high probability of death to become an official Hunter. He befriends the revenge-driven Kurapika: 1 anime
# disguising themselves as human beings. They feed off blood and hide themselves within the human world. An organization known as the Red Shield has been waging a private war to wipe them out and now the struggle has grown. Saya's journey for the truth has begun.<br>: 1 anime
# has escaped and is being hunted by the RUC Security Bureau. She encounters the bounty hunter Roy and he adopts her as his daughter after being hired as a bodygaurd for Miranda.<br><br>: 1 anime
# neither sister realizes that there is one man who has an even greater power than the Dragons: 1 anime
# Fokker: 1 anime
# engages the creature in an attempt to save his village. During the battle: 1 anime
# used for gunpowder and other machinery. However: 1 anime
# he attempts to create peace and befriend the Wolf Clan. However: 1 anime
# Ayato Kamina meets Reika Mishima: 1 anime
# informing him that she was sent to get him by the Organization TERRA: 1 anime
# and upon her singing his mother appears atop the Dolem that had stopped the TERRA Invasion. In the battle Ayato's mother is injured: 1 anime
# Kirara: 1 anime
# Hanamichi tells her he loves basketball: 1 anime
# who is very popular among the girls: 1 anime
# the young witch Nina: 1 anime
# Nina: 1 anime
# Keitaro thinks he will fail the paper and tries to escape from Hinata Lodge and forget all the memories with it. By a stroke of luck he meets Seta: 1 anime
# has been shattered. The warring tribes of Light and Shadow blame each other: 1 anime
# lusts for his bride-to-be: 1 anime
# the leader of the Tribe of Light. Fabris` army loses the battle: 1 anime
# a Light Tribe sorceress who has been taken captive. As Astral penetrates Maria: 1 anime
# Michelle: 1 anime
# but the girl: 1 anime
# they began sharing a strong bond of friendship. Then the other day: 1 anime
# that the very A.W. was Kei and that he was Miki's problem. Will Kei be able to confess his love or will he forever be number two to his own alternate identity? <br><br>: 1 anime
# Ryoko (the manager who`s sweet on Koji by working him very hard): 1 anime
# Susuki gets to work to find the killer. While digging for the killer: 1 anime
# and one version which has lost all sexual content.</i>": 1 anime
#
# === Top 5 Highest Rated Anime ===
# +--------------------------------------------------+-----+-----------------------------------+-----------+
# |title                                             |score|genres                             |score_float|
# +--------------------------------------------------+-----+-----------------------------------+-----------+
# |HUNTER×HUNTER OVA                                 |81   |Action, Adventure, Fantasy         |81.0       |
# |Initial D FOURTH STAGE                            |80   |Action, Drama, Sports              |80.0       |
# |BECK                                              |80   |Comedy, Drama, Music, Slice of Life|80.0       |
# |Kidou Senshi Gundam 0080: Pocket no Naka no Sensou|80   |Adventure, Drama, Mecha, Sci-Fi    |80.0       |
# |<i>Note: Episodes 11                              |79   |Action, Adventure, Drama, Fantasy  |79.0       |
# +--------------------------------------------------+-----+-----------------------------------+-----------+
#
#
# === Average Score per Genre ===
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+-----------+
# |genre                                                                                                                                                                                                                                                         |average_score|anime_count|
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+-----------+
# |Music                                                                                                                                                                                                                                                         |80.0         |1          |
# |Sports                                                                                                                                                                                                                                                        |79.0         |2          |
# |Dr. Tenma's beliefs are shaken as his actions that night are shown to have much broader consequences than he could have imagined. Leaving behind his life as a surgeon he embarks on a journey across the country to unravel the mystery of the boy he saved."|74.0         |1          |
# |Mahou Shoujo                                                                                                                                                                                                                                                  |73.33        |3          |
# |Action                                                                                                                                                                                                                                                        |72.39        |18         |
# |Adventure                                                                                                                                                                                                                                                     |71.12        |17         |
# |Slice of Life                                                                                                                                                                                                                                                 |70.86        |7          |
# |Drama                                                                                                                                                                                                                                                         |70.8         |30         |
# |Mecha                                                                                                                                                                                                                                                         |69.88        |8          |
# |Supernatural                                                                                                                                                                                                                                                  |68.92        |12         |
# |Mystery                                                                                                                                                                                                                                                       |68.67        |3          |
# |Psychological                                                                                                                                                                                                                                                 |68.67        |3          |
# |Comedy                                                                                                                                                                                                                                                        |68.44        |25         |
# |Sci-Fi                                                                                                                                                                                                                                                        |67.75        |12         |
# |Romance                                                                                                                                                                                                                                                       |67.45        |22         |
# |Horror                                                                                                                                                                                                                                                        |67.0         |1          |
# |Fantasy                                                                                                                                                                                                                                                       |66.9         |20         |
# |Ecchi                                                                                                                                                                                                                                                         |64.5         |4          |
# |but her relationship with an ex-worker for her evil grandpa may be a distraction. "                                                                                                                                                                           |24.0         |1          |
# |and one version which has lost all sexual content.</i>"                                                                                                                                                                                                       |2.0          |1          |
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-------------+-----------+
# only showing top 20 rows
#
#
# === Average Number of Episodes per Genre ===
# +-----+------------+-----------+
# |genre|avg_episodes|anime_count|
# +-----+------------+-----------+
# |101.0|83.0        |1          |
# |220.0|79.0        |1          |
# |94.0 |79.0        |1          |
# |75.0 |78.0        |1          |
# |145.0|76.0        |1          |
# |22.0 |76.0        |1          |
# |43.0 |76.0        |1          |
# |69.0 |75.0        |1          |
# |18.0 |75.0        |1          |
# |178.0|75.0        |1          |
# |50.0 |73.8        |5          |
# |64.0 |73.0        |1          |
# |52.0 |72.3        |4          |
# |49.0 |72.0        |3          |
# |1.0  |71.1        |15         |
# |26.0 |70.8        |33         |
# |25.0 |69.3        |3          |
# |74.0 |69.0        |1          |
# |51.0 |68.5        |2          |
# |7.0  |68.0        |1          |
# +-----+------------+-----------+
# only showing top 20 rows
#
#
# === Genre with Highest Average Score (min 5 anime) ===
# Genre: Action
# Average Score: 72.39
# Number of Anime: 18
#
# === Most Common Genre Combinations ===
# +------+-----+
# |genres|count|
# +------+-----+
# |NULL  |299  |
# |26.0  |33   |
# |13.0  |18   |
# |1.0   |15   |
# |12.0  |14   |
# |24.0  |11   |
# |50.0  |5    |
# |4.0   |5    |
# |3.0   |5    |
# |52.0  |4    |
# +------+-----+
